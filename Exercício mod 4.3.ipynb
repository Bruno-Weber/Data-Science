# %% [markdown]
# # Tarefa 03
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os Tutores
# - Divirta-se :)

# %%
import pandas as pd
import requests

# %% [markdown]
# ####  1) Lendo de APIs
# Vimos em aula como carregar dados públicos do governo através de um API (*Application Programming Interface*). No exemplo de aula, baixamos os dados de pedidos de verificação de limites (PVL) realizados por estados, e selecionamos apenas aqueles referentes ao estado de São Paulo.
#
# 1. Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.
# 2. Quais são os três *status* das solicitações mais frequentes na base? Quais são suas frequências?
# 3. Construa uma nova variável que contenha o ano do **status**. Observe que ```data_status``` vem como tipo *object* no **DataFrame**. Dica: você pode usar o método ```.str``` para transformar o tipo da variável em string, em seguida um método como [**slice()**](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.slice.html) ou [**split()**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html).
# 4. Indique a frequência de cada ano do campo construído no item (3).

# %%
url_rj = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=RJ&tipo_interessado=Estado'
r_rj = requests.get(url_rj)
print(f'Código: {r_rj.status_code}.')
# Out:
# Código: 200.

# %%
data_json_rj = r_rj.json()
print(data_json_rj['items'])
# Out:
# [{'id_pleito': 11306, 'tipo_interessado': 'Estado', 'interessado': 'Rio de Janeiro', 'cod_ibge': 33, 'uf': 'RJ', 'num_pvl': None, 'status': 'Encaminhado à PGFN com manifestação técnica favorável', 'num_processo': '17944.001408/2009-98', 'data_protocolo': '2009-11-23T02:00:00Z', 'tipo_operacao': 'Operação contratual externa (com garantia da União)', 'finalidade': 'Fortalecimento Institucional', 'tipo_credor': 'Instituição Financeira Internacional', 'credor': 'Banco Internacional para Reconstrução e Desenvolvimento', 'moeda': 'Dólar dos EUA', 'valor': 485000000, 'pvl_assoc_divida': 1, 'pvl_contradado_credor': 0, 'data_status': '25/11/2009'}, {'id_pleito': 8528, 'tipo_interessado': 'Estado', 'interessado': 'Rio de Janeiro', 'cod_ibge': 33, 'uf': 'RJ', 'num_pvl': None, 'status': 'Deferido', 'num_processo': '17944.000793/2009-56', 'data_protocolo': '2009-07-17T03:00:00Z', 'tipo_operacao': 'Operação contratual interna', 'finalidade': 'Aquisição de terrenos, imóveis e/ou construção de instalações', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Banco Nacional de Desenvolvimento Econômico e Social', 'moeda': 'Real', 'valor': 157000000, 'pvl_assoc_divida': 1, 'pvl_contradado_credor': 0, 'data_status': '24/07/2009'}, {'id_pleito': 13629, 'tipo_interessado': 'Estado', 'interessado': 'Rio de Janeiro', 'cod_ibge': 33, 'uf': 'RJ', 'num_pvl': None, 'status': 'Deferido', 'num_processo': '19405.000040/2002-05', 'data_protocolo': '2002-06-20T03:00:00Z', 'tipo_operacao': 'Operação contratual interna', 'finalidade': 'Aquisição de máquinas, equipamentos e veículos', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Banco Nacional de Desenvolvimento Econômico e Social', 'moeda': 'Real', 'valor': 43527550, 'pvl_assoc_divida': 1, 'pvl_contradado_credor': 0, 'data_status': '27/06/2002'}, {'id_pleito': 13483, 'tipo_interessado': 'Estado', 'interessado': 'Rio de Janeiro', 'cod_ibge': 33, 'uf': 'RJ', 'num_pvl': None, 'status': 'Deferido', 'num_processo': '19405.000010/2004-52', 'data_protocolo': '2006-02-15T02:00:00Z', 'tipo_operacao': 'Operação contratual interna', 'finalidade': 'Renegociação de dívidas', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Banco Nacional de Desenvolvimento Econômico e Social', 'moeda': 'Real', 'valor': 847526319.24, 'pvl_assoc_divida': 1, 'pvl_contradado_credor': 0, 'data_status': '01/03/2006'}, {'id_pleito': 9102, 'tipo_interessado': 'Estado', 'interessado': 'Rio de Janeiro', 'cod_ibge': 33, 'uf': 'RJ', 'num_pvl': None, 'status': 'Encaminhado à PGFN com manifestação técnica favorável', 'num_processo': '17944.000903/2009-80', 'data_protocolo': '2009-07-29T03:00:00Z', 'tipo_operacao': 'Operação contratual interna (com garantia da União)', 'finalidade': 'PEF - Programa Emergencial de Financiamento dos Estados/DF', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Banco do Brasil S/A', 'moeda': 'Real', 'valor': 61108000, 'pvl_assoc_divida': 1, 'pvl_contradado_credor': 0, 'data_status': '06/08/2009'}, {'id_pleito': 21660, 'tipo_interessado': 'Estado', 'interessado': 'Rio de Janeiro', 'cod_ibge': 33, 'uf': 'RJ', 'num_pvl': '00000.000000/2026-68', 'status': 'Arquivado a pedido', 'num_processo': '17944.000245/2016-55', 'data_protocolo': '2016-03-11T03:00:00Z', 'tipo_operacao': 'Operação contratual interna (com garantia da União)', 'finalidade': 'Fortalecimento Institucional', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Banco do Brasil S/A', 'moeda': 'Real', 'valor': 1000000000, 'pvl_assoc_divida': 0, 'pvl_contradado_credor': 0, 'data_status': '16/05/2016'}, {'id_pleito': 5923, 'tipo_interessado': 'Estado', 'interessado': 'Rio de Janeiro', 'cod_ibge': 33, 'uf': 'RJ', 'num_pvl': None, 'status': 'Encaminhado à PGFN com manifestação técnica favorável', 'num_processo': '17944.000234/2012-41', 'data_protocolo': '2012-04-16T03:00:00Z', 'tipo_operacao': 'Operação contratual externa (com garantia da União)', 'finalidade': 'Infraestrutura', 'tipo_credor': 'Instituição Finance ...

# %%
df_rj = pd.DataFrame(data_json_rj['items'])
df_rj.head()
# Out:
#    id_pleito tipo_interessado     interessado  cod_ibge  uf num_pvl  \
# 0      11306           Estado  Rio de Janeiro        33  RJ    None
# 1       8528           Estado  Rio de Janeiro        33  RJ    None
# 2      13629           Estado  Rio de Janeiro        33  RJ    None
# 3      13483           Estado  Rio de Janeiro        33  RJ    None
# 4       9102           Estado  Rio de Janeiro        33  RJ    None
#
#                                               status          num_processo  \
# 0  Encaminhado à PGFN com manifestação técnica fa...  17944.001408/2009-98
# 1                                           Deferido  17944.000793/2009-56
# 2                                           Deferido  19405.000040/2002-05
# 3                                           Deferido  19405.000010/2004-52
# 4  Encaminhado à PGFN com manifestação técnica fa...  17944.000903/2009-80
#
#          data_protocolo                                      tipo_operacao  \
# 0  2009-11-23T02:00:00Z  Operação contratual externa (com garantia da U...
# 1  2009-07-17T03:00:00Z                        Operação contratual interna
# 2  2002-06-20T03:00:00Z                        Operação contratual interna
# 3  2006-02-15T02:00:00Z                        Operação contratual interna
# 4  2009-07-29T03:00:00Z  Operação contratual interna (com garantia da U...
#
#                                           finalidade  \
# 0                       Fortalecimento Institucional
# 1  Aquisição de terrenos, imóveis e/ou construção...
# 2     Aquisição de máquinas, equipamentos e veículos
# 3                            Renegociação de dívidas
# 4  PEF - Programa Emergencial de Financiamento do...
#
#                             tipo_credor  \
# 0  Instituição Financeira Internacional
# 1       Instituição Financeira Nacional
# 2       Instituição Financeira Nacional
# 3       Instituição Financeira Nacional
# 4       Instituição Financeira Nacional
#
#                                               credor          moeda  \
# 0  Banco Internacional para Reconstrução e Desenv...  Dólar dos EUA
# 1  Banco Nacional de Desenvolvimento Econômico e ...           Real
# 2  Banco Nacional de Desenvolvimento Econômico e ...           Real
# 3  Banco Nacional de Desenvolvimento Econômico e ...           Real
# 4                                Banco do Brasil S/A           Real
#
#           valor  pvl_assoc_divida  pvl_contradado_credor data_status
# 0  4.850000e+08                 1                      0  25/11/2009
# 1  1.570000e+08                 1                      0  24/07/2009
# 2  4.352755e+07                 1                      0  27/06/2002
# 3  8.475263e+08                 1                      0  01/03/2006
# 4  6.110800e+07                 1                      0  06/08/2009

# %%
df_rj.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id_pleito              52 non-null     int64
#  1   tipo_interessado       52 non-null     object
#  2   interessado            52 non-null     object
#  3   cod_ibge               52 non-null     int64
#  4   uf                     52 non-null     object
#  5   num_pvl                3 non-null      object
#  6   status                 52 non-null     object
#  7   num_processo           52 non-null     object
#  8   data_protocolo         52 non-null     object
#  9   tipo_operacao          52 non-null     object
#  10  finalidade             52 non-null     object
#  11  tipo_credor            52 non-null     object
#  12  credor                 52 non-null     object
#  13  moeda                  52 non-null     object
#  14  valor                  52 non-null     float64
#  15  pvl_assoc_divida       52 non-null     int64
#  16  pvl_contradado_credor  52 non-null     int64
#  17  data_status            52 non-null     object
# dtypes: float64(1), int64(4), object(13)
# memory usage: 7.4+ KB

# %%
df_rj['status'].value_counts()
# Out:
# Encaminhado à PGFN com manifestação técnica favorável    34
# Deferido                                                 14
# Arquivado a pedido                                        3
# Arquivado por decurso de prazo                            1
# Name: status, dtype: int64

# %%
df_rj['data_status'] = pd.to_datetime(df_rj['data_status'], format='%d/%m/%Y')


df_rj['ano_status'] = df_rj['data_status'].dt.year


df_status_ano = df_rj[['status', 'ano_status']]
df_status_ano
# Out:
#                                                status  ano_status
# 0   Encaminhado à PGFN com manifestação técnica fa...        2009
# 1                                            Deferido        2009
# 2                                            Deferido        2002
# 3                                            Deferido        2006
# 4   Encaminhado à PGFN com manifestação técnica fa...        2009
# 5                                  Arquivado a pedido        2016
# 6   Encaminhado à PGFN com manifestação técnica fa...        2012
# 7                                            Deferido        2011
# 8                      Arquivado por decurso de prazo        2016
# 9   Encaminhado à PGFN com manifestação técnica fa...        2012
# 10                                           Deferido        2009
# 11  Encaminhado à PGFN com manifestação técnica fa...        2009
# 12                                           Deferido        2008
# 13  Encaminhado à PGFN com manifestação técnica fa...        2016
# 14  Encaminhado à PGFN com manifestação técnica fa...        2011
# 15                                           Deferido        2010
# 16  Encaminhado à PGFN com manifestação técnica fa...        2011
# 17  Encaminhado à PGFN com manifestação técnica fa...        2012
# 18  Encaminhado à PGFN com manifestação técnica fa...        2012
# 19                                           Deferido        2002
# 20                                           Deferido        2012
# 21                                 Arquivado a pedido        2014
# 22  Encaminhado à PGFN com manifestação técnica fa...        2012
# 23  Encaminhado à PGFN com manifestação técnica fa...        2016
# 24  Encaminhado à PGFN com manifestação técnica fa...        2013
# 25  Encaminhado à PGFN com manifestação técnica fa...        2009
# 26  Encaminhado à PGFN com manifestação técnica fa...        2012
# 27  Encaminhado à PGFN com manifestação técnica fa...        2013
# 28                                           Deferido        2002
# 29                                           Deferido        2009
# 30  Encaminhado à PGFN com manifestação técnica fa...        2012
# 31  Encaminhado à PGFN com manifestação técnica fa...        2008
# 32  Encaminhado à PGFN com manifestação técnica fa...        2014
# 33  Encaminhado à PGFN com manifestação técnica fa...        2014
# 34                                           Deferido        2010
# 35  Encaminhado à PGFN com manifestação técnica fa...        2012
# 36  Encaminhado à PGFN com manifestação técnica fa...        2013
# 37  Encaminhado à PGFN com manifestação técnica fa...        2012
# 38  Encaminhado à PGFN com manifestação técnica fa...        2011
# 39                                 Arquivado a pedido        2013
# 40  Encaminhado à PGFN com manifestação técnica fa...        2013
# 41  Encaminhado à PGFN com manifestação técnica fa...        2013
# 42                                           Deferido        2006
# 43  Encaminhado à PGFN com manifestação técnica fa...        2009
# 44  Encaminhado à PGFN com manifestação técnica fa...        2011
# 45  Encaminhado à PGFN com manifestação técnica fa...        2011
# 46  Encaminhado à PGFN com manifestação técnica fa...        2012
# 47  Encaminhado à PGFN com manifestação técnica fa...        2014
# 48  Encaminhado à PGFN com manifestação técnica fa...        2010
# 49                                           Deferido        2002
# 50  Encaminhado à PGFN com manifestação técnica fa...        2013
# 51  Encaminhado à PGFN com manifestação técnica fa...        2009

# %%
df_rj['ano_status'].value_counts()
# Out:
# 2012    11
# 2009     9
# 2013     7
# 2011     6
# 2002     4
# 2016     4
# 2014     4
# 2010     3
# 2006     2
# 2008     2
# Name: ano_status, dtype: int64

# %% [markdown]
# ####  2) Melhorando a interação com o API
# Observe dois URLs de consultas diferentes, por exemplo o URL utilizado em aula, e o URL feito no exercício anterior. Compare-os e observe as diferenças.
#
# 1. Faça uma função em Python que recebe como argumento o UF da consulta e o tipo de interessado (```'Estado'```ou ```Município```), e que devolve os dados da consulta no formato *DataFrame*.
# 2. Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com *status* em 'Arquivado por decurso de prazo' estão registradas?
# 3. Qual é o município da Bahia com mais solicitações deferidas?
# 4. Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'

# %%
df_rj.head()
# Out:
#    id_pleito tipo_interessado     interessado  cod_ibge  uf num_pvl  \
# 0      11306           Estado  Rio de Janeiro        33  RJ    None
# 1       8528           Estado  Rio de Janeiro        33  RJ    None
# 2      13629           Estado  Rio de Janeiro        33  RJ    None
# 3      13483           Estado  Rio de Janeiro        33  RJ    None
# 4       9102           Estado  Rio de Janeiro        33  RJ    None
#
#                                               status          num_processo  \
# 0  Encaminhado à PGFN com manifestação técnica fa...  17944.001408/2009-98
# 1                                           Deferido  17944.000793/2009-56
# 2                                           Deferido  19405.000040/2002-05
# 3                                           Deferido  19405.000010/2004-52
# 4  Encaminhado à PGFN com manifestação técnica fa...  17944.000903/2009-80
#
#          data_protocolo                                      tipo_operacao  \
# 0  2009-11-23T02:00:00Z  Operação contratual externa (com garantia da U...
# 1  2009-07-17T03:00:00Z                        Operação contratual interna
# 2  2002-06-20T03:00:00Z                        Operação contratual interna
# 3  2006-02-15T02:00:00Z                        Operação contratual interna
# 4  2009-07-29T03:00:00Z  Operação contratual interna (com garantia da U...
#
#                                           finalidade  \
# 0                       Fortalecimento Institucional
# 1  Aquisição de terrenos, imóveis e/ou construção...
# 2     Aquisição de máquinas, equipamentos e veículos
# 3                            Renegociação de dívidas
# 4  PEF - Programa Emergencial de Financiamento do...
#
#                             tipo_credor  \
# 0  Instituição Financeira Internacional
# 1       Instituição Financeira Nacional
# 2       Instituição Financeira Nacional
# 3       Instituição Financeira Nacional
# 4       Instituição Financeira Nacional
#
#                                               credor          moeda  \
# 0  Banco Internacional para Reconstrução e Desenv...  Dólar dos EUA
# 1  Banco Nacional de Desenvolvimento Econômico e ...           Real
# 2  Banco Nacional de Desenvolvimento Econômico e ...           Real
# 3  Banco Nacional de Desenvolvimento Econômico e ...           Real
# 4                                Banco do Brasil S/A           Real
#
#           valor  pvl_assoc_divida  pvl_contradado_credor data_status
# 0  4.850000e+08                 1                      0  25/11/2009
# 1  1.570000e+08                 1                      0  24/07/2009
# 2  4.352755e+07                 1                      0  27/06/2002
# 3  8.475263e+08                 1                      0  01/03/2006
# 4  6.110800e+07                 1                      0  06/08/2009

# %%
#Data Frame MG

url_mg = 'http://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=MG&tipo_interessado=Estado'
r_mg = requests.get(url_mg)
data_json_mg = r_mg.json()
df_mg = pd.DataFrame(data_json_mg['items'])
df_mg.head()
# Out:
#    id_pleito tipo_interessado   interessado  cod_ibge  uf  \
# 0      20458           Estado  Minas Gerais        31  MG
# 1       7032           Estado  Minas Gerais        31  MG
# 2      12286           Estado  Minas Gerais        31  MG
# 3      13641           Estado  Minas Gerais        31  MG
# 4      13441           Estado  Minas Gerais        31  MG
#
#                 num_pvl                                             status  \
# 0  00000.000000/2020-68                                 Arquivado a pedido
# 1                  None  Encaminhado à PGFN com manifestação técnica fa...
# 2                  None                                          Arquivado
# 3                  None                                           Deferido
# 4                  None                                           Deferido
#
#            num_processo        data_protocolo  \
# 0  17944.001085/2015-81  2015-11-23T02:00:00Z
# 1  17944.000482/2012-92  2012-10-11T03:00:00Z
# 2  17944.001650/2008-81  2008-12-31T02:00:00Z
# 3  19405.000042/2004-58  2004-11-26T02:00:00Z
# 4  19405.000001/2005-42  2005-08-16T03:00:00Z
#
#                                        tipo_operacao  \
# 0  Operação contratual externa (com garantia da U...
# 1  Operação contratual externa (com garantia da U...
# 2  Operação contratual externa (com garantia da U...
# 3                        Operação contratual interna
# 4                        Operação contratual interna
#
#                                           finalidade  \
# 0                                     Multissetorial
# 1  Reestruturação e recomposição do principal de ...
# 2                                     Infraestrutura
# 3                                     Infraestrutura
# 4                                     Infraestrutura
#
#                             tipo_credor  \
# 0  Instituição Financeira Internacional
# 1  Instituição Financeira Internacional
# 2  Instituição Financeira Internacional
# 3       Instituição Financeira Nacional
# 4       Instituição Financeira Nacional
#
#                                               credor          moeda  \
# 0            Banco Interamericano de Desenvolvimento  Dólar dos EUA
# 1  Banco Internacional para Reconstrução e Desenv...  Dólar dos EUA
# 2            Banco Interamericano de Desenvolvimento  Dólar dos EUA
# 3  Banco Nacional de Desenvolvimento Econômico e ...           Real
# 4                    Banco do Nordeste do Brasil S/A  Dólar dos EUA
#
#          valor  pvl_assoc_divida  pvl_contradado_credor data_status
# 0   50000000.0                 0                      0  29/04/2016
# 1  450000000.0                 1                      0  15/10/2012
# 2   50000000.0                 0                      0  23/01/2009
# 3   53770000.0                 1                      0  08/12/2004
# 4   27534000.0                 1                      0  29/08/2005

# %%
estado_uf = input(f'Insira a UF de interesse: ')
estado_ou_municipio = input(f'Escreva Estado ou Municipio para filtrar: ')

url = "https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=" + estado_uf + "&tipo_interessado=" + estado_ou_municipio
r = requests.get(url)
data_json = r.json()
df_escolhido = pd.DataFrame(data_json['items'])


def escolha(estado_uf, estado_ou_municipio):
    print(df_escolhido)
escolha(estado_uf, estado_ou_municipio)
print(url)
# Out:
# Insira a UF de interesse: MG
# Escreva Estado ou Municipio para filtrar: Belo Horizonte
# Empty DataFrame
# Columns: []
# Index: []
# https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=MG&tipo_interessado=Belo Horizonte

# %%
df_rj['data_status'] = pd.to_datetime(df_rj['data_status'], format='%d/%m/%Y')

df_rj['ano_status'] = df_rj['data_status'].dt.year

df_status_ano = df_rj[['status', 'ano_status']]
df_status_ano

# %%
arquivado = df_mg.loc[df_mg.status == 'Arquivado por decurso de prazo']
arquivado['status'].value_counts()
# Out:
# Arquivado por decurso de prazo    1
# Name: status, dtype: int64

# %%
url_ba = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=BA&tipo_interessado=Munic%C3%ADpio'
r_ba = requests.get(url_ba)
data_json_ba = r_ba.json()
df_ba = pd.DataFrame(data_json_ba['items'])
df_ba.head()
# Out:
#    id_pleito tipo_interessado             interessado  cod_ibge  uf  \
# 0      22007        Município  Luís Eduardo Magalhães   2919553  BA
# 1       9347        Município             Nova Fátima   2922730  BA
# 2       9425        Município          Piraí do Norte   2924678  BA
# 3      18608        Município            Encruzilhada   2910404  BA
# 4      18617        Município       Ribeirão do Largo   2926657  BA
#
#                 num_pvl                          status          num_processo  \
# 0  00000.000000/2028-74                        Deferido  17944.000356/2016-61
# 1                  None                       Arquivado  17944.000960/2008-88
# 2                  None  Arquivado por decurso de prazo  17944.000979/2012-19
# 3                  None                        Deferido  19407.000064/2002-36
# 4                  None                        Deferido  19407.000067/2002-70
#
#          data_protocolo                tipo_operacao  \
# 0  2016-03-23T03:00:00Z  Operação contratual interna
# 1  2008-08-27T03:00:00Z  Operação contratual interna
# 2  2012-08-22T03:00:00Z  Operação contratual interna
# 3  2002-06-28T03:00:00Z  Operação contratual interna
# 4  2003-01-31T02:00:00Z  Operação contratual interna
#
#                                        finalidade  \
# 0                                  Infraestrutura
# 1                             Caminho da Escola 2
# 2                                            PMAT
# 3  Aquisição de máquinas, equipamentos e veículos
# 4  Aquisição de máquinas, equipamentos e veículos
#
#                        tipo_credor                                     credor  \
# 0  Instituição Financeira Nacional  Agência de Fomento do Estado da Bahia S/A
# 1  Instituição Financeira Nacional                        Banco do Brasil S/A
# 2  Instituição Financeira Nacional  Agência de Fomento do Estado da Bahia S/A
# 3  Instituição Financeira Nacional  Agência de Fomento do Estado da Bahia S/A
# 4  Instituição Financeira Nacional  Agência de Fomento do Estado da Bahia S/A
#
#   moeda       valor  pvl_assoc_divida  pvl_contradado_credor data_status
# 0  Real  14900000.0                 0                      0  12/04/2016
# 1  Real    286700.0                 0                      0  07/11/2008
# 2  Real   2100000.0                 0                      0  14/06/2013
# 3  Real    500000.0                 0                      0  25/02/2003
# 4  Real    500000.0                 0                      0  20/02/2003

# %%
df_ba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 896 entries, 0 to 895
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id_pleito              896 non-null    int64
#  1   tipo_interessado       896 non-null    object
#  2   interessado            896 non-null    object
#  3   cod_ibge               896 non-null    int64
#  4   uf                     896 non-null    object
#  5   num_pvl                309 non-null    object
#  6   status                 896 non-null    object
#  7   num_processo           770 non-null    object
#  8   data_protocolo         770 non-null    object
#  9   tipo_operacao          896 non-null    object
#  10  finalidade             896 non-null    object
#  11  tipo_credor            896 non-null    object
#  12  credor                 896 non-null    object
#  13  moeda                  896 non-null    object
#  14  valor                  896 non-null    float64
#  15  pvl_assoc_divida       896 non-null    int64
#  16  pvl_contradado_credor  896 non-null    int64
#  17  data_status            896 non-null    object
# dtypes: float64(1), int64(4), object(13)
# memory usage: 126.1+ KB

# %%
ba_sol_deferidas = df_ba['interessado'].loc[df_ba.status == 'Deferido']
# ba_sol_deferidas
ba_sol_deferidas.value_counts()
# Out:
# Luís Eduardo Magalhães    14
# Vitória da Conquista      11
# Camaçari                  10
# Lauro de Freitas          10
# Barreiras                  9
#                           ..
# Paratinga                  1
# Caturama                   1
# Cruz Das Almas             1
# Itabuna                    1
# Ituaçu                     1
# Name: interessado, Length: 176, dtype: int64

# %%
url_ba_estado = 'http://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=BA&tipo_interessado=Estado'
r_ba_estado = requests.get(url_ba_estado)
data_json_ba_estado = r_ba_estado.json()
df_ba_estado = pd.DataFrame(data_json_ba_estado['items'])
df_ba_estado.head()
# Out:
#    id_pleito tipo_interessado interessado  cod_ibge  uf               num_pvl  \
# 0      18633           Estado       Bahia        29  BA                  None
# 1      20438           Estado       Bahia        29  BA  00000.000000/2017-83
# 2      18531           Estado       Bahia        29  BA                  None
# 3      43670           Estado       Bahia        29  BA  PVL02.001988/2020-66
# 4      10431           Estado       Bahia        29  BA                  None
#
#                                               status          num_processo  \
# 0                                           Deferido  19407.000073/2003-16
# 1                                           Deferido  17944.001076/2015-90
# 2                                           Deferido  19407.000044/2002-65
# 3                                           Deferido  17944.105210/2020-98
# 4  Encaminhado à PGFN com manifestação técnica fa...  17944.001198/2012-33
#
#          data_protocolo                                      tipo_operacao  \
# 0  2004-01-30T02:00:00Z                        Operação contratual interna
# 1  2016-03-02T18:35:28Z                        Operação contratual interna
# 2  2002-06-11T03:00:00Z                        Operação contratual interna
# 3  2021-01-04T19:42:50Z                              Concessão de garantia
# 4  2013-07-04T03:00:00Z  Operação contratual externa (com garantia da U...
#
#                                           finalidade  \
# 0                                  Saneamento básico
# 1                                     Pró-Transporte
# 2                                  Saneamento básico
# 3  Concessão de garantia a empresa estatal não de...
# 4                                     Multissetorial
#
#                             tipo_credor  \
# 0       Instituição Financeira Nacional
# 1       Instituição Financeira Nacional
# 2       Instituição Financeira Nacional
# 3  Instituição Financeira Internacional
# 4  Instituição Financeira Internacional
#
#                                     credor          moeda         valor  \
# 0                  Caixa Econômica Federal           Real  2.150132e+08
# 1                  Caixa Econômica Federal           Real  8.000000e+08
# 2                  Caixa Econômica Federal           Real  7.360877e+06
# 3           Kreditanstalt für Wiederaufbau           Euro  6.000000e+07
# 4  Banco Interamericano de Desenvolvimento  Dólar dos EUA  5.082290e+07
#
#    pvl_assoc_divida  pvl_contradado_credor data_status
# 0                 1                      0  18/03/2004
# 1                 1                      0  31/03/2016
# 2                 1                      0  05/07/2002
# 3                 0                      0  07/01/2021
# 4                 1                      0  09/08/2013

# %%
df_ba_estado.to_csv('./output/df_ba_estado.csv', index= False, encoding='utf-8-sig', sep=';')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
# ----> 1 df_ba_estado.to_csv('./output/df_ba_estado.csv', index= False, encoding='utf-8-sig', sep=';')
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:3551, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3540 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3542 formatter = DataFrameFormatter(
#    3543     frame=df,
#    3544     header=header,
#    (...)
#    3548     decimal=decimal,
#    3549 )
# -> 3551 return DataFrameRenderer(formatter).to_csv(
#    3552     path_or_buf,
#    3553     line_terminator=line_terminator,
#    3554     sep=sep,
#    3555     encoding=encoding,
#    3556     errors=errors,
#    3557     compression=compression,
#    3558     quoting=quoting,
#    3559     columns=columns,
#    3560     index_label=index_label,
#    3561     mode=mode,
#    3562     chunksize=chunksize,
#    3563     quotechar=quotechar,
#    3564     date_format=date_format,
#    3565     doublequote=doublequote,
#    3566     escapechar=escapechar,
#    3567     storage_options=storage_options,
#    3568 )
#
# File ~\anaconda3\lib\site-packages\pandas\io\formats\format.py:1180, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1159     created_buffer = False
#    1161 csv_formatter = CSVFormatter(
#    1162     path_or_buf=path_or_buf,
#    1163     line_terminator=line_terminator,
#    (...)
#    1178     formatter=self.fmt,
#    1179 )
# -> 1180 csv_formatter.save()
#    1182 if created_buffer:
#    1183     assert isinstance(path_or_buf, StringIO)
#
# File ~\anaconda3\lib\site-packages\pandas\io\formats\csvs.py:241, in CSVFormatter.save(self)
#     237 """
#     238 Create the writer & save.
#     239 """
#     240 # apply compression and byte/text conversion
# --> 241 with get_handle(
#     242     self.filepath_or_buffer,
#     243     self.mode,
#     244     encoding=self.encoding,
#     245     errors=self.errors,
#     246     compression=self.compression,
#     247     storage_options=self.storage_options,
#     248 ) as handles:
#     249
#     250     # Note: self.encoding is irrelevant here
#     251     self.writer = csvlib.writer(
#     252         handles.handle,
#     253         lineterminator=self.line_terminator,
#    (...)
#     258         quotechar=self.quotechar,
#     259     )
#     261     self._save()
#
# File ~\anaconda3\lib\site-packages\pandas\io\common.py:697, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     695 # Only for write methods
#     696 if "r" not in mode and is_path:
# --> 697     check_parent_directory(str(handle))
#     699 if compression:
#     700     if compression != "zstd":
#     701         # compression libraries do not like an explicit text-mode
#
# File ~\anaconda3\lib\site-packages\pandas\io\common.py:571, in check_parent_directory(path)
#     569 parent = Path(path).parent
#     570 if not parent.is_dir():
# --> 571     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: 'output'
